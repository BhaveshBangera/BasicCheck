# %%
# %matplotlib notebook

import matplotlib.pyplot as plt

# %%
plt.plot([0, 1, 2, 5])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="637">

# %%
fig.suptitle('Suptitle', fontsize=10, fontweight='bold')
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)

# %%
ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.text(4, 6, 'Text in Data Coords', bbox={'facecolor':'yellow', 'alpha':0.5, 'pad':10})
# Out:
# Text(4,6,'Text in Data Coords')

# %%
ax.axis([0, 10, 0, 10])
# Out:
# [0, 10, 0, 10]

# %%
ax.plot([4], [2], 'o')

# %%
ax.annotate('Example of Annotate', xy=(4,2), xytext=(8,4), arrowprops=dict(facecolor='green', shrink=0.05))
# Out:
# Text(8,4,'Example of Annotate')

# %%
plt.show()

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\BHAVESH\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# %matplotlib inline
plt.show()

# %%
plt.show()

# %%
plt.show()

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
